# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Sleep.csv")
df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
df.shape
# Out:
# (374, 13)

# %%
df.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
df.isnull().sum()
# Out:
# Person ID                    0
# Gender                       0
# Age                          0
# Occupation                   0
# Sleep Duration               0
# Quality of Sleep             0
# Physical Activity Level      0
# Stress Level                 0
# BMI Category                 0
# Blood Pressure               0
# Heart Rate                   0
# Daily Steps                  0
# Sleep Disorder             219
# dtype: int64

# %%
df['Sleep Disorder']=df['Sleep Disorder'].fillna('None')

# %%
df.isnull().sum()
# Out:
# Person ID                  0
# Gender                     0
# Age                        0
# Occupation                 0
# Sleep Duration             0
# Quality of Sleep           0
# Physical Activity Level    0
# Stress Level               0
# BMI Category               0
# Blood Pressure             0
# Heart Rate                 0
# Daily Steps                0
# Sleep Disorder             0
# dtype: int64

# %%
df['Sleep Disorder'].value_counts()
# Out:
# Sleep Disorder
# None           219
# Sleep Apnea     78
# Insomnia        77
# Name: count, dtype: int64

# %%
df.drop('Person ID',axis=1,inplace=True)

# %%
df.describe()
# Out:
#               Age  Sleep Duration  Quality of Sleep  Physical Activity Level  \
# count  374.000000      374.000000        374.000000               374.000000
# mean    42.184492        7.132086          7.312834                59.171123
# std      8.673133        0.795657          1.196956                20.830804
# min     27.000000        5.800000          4.000000                30.000000
# 25%     35.250000        6.400000          6.000000                45.000000
# 50%     43.000000        7.200000          7.000000                60.000000
# 75%     50.000000        7.800000          8.000000                75.000000
# max     59.000000        8.500000          9.000000                90.000000
#
#        Stress Level  Heart Rate   Daily Steps
# count    374.000000  374.000000    374.000000
# mean       5.385027   70.165775   6816.844920
# std        1.774526    4.135676   1617.915679
# min        3.000000   65.000000   3000.000000
# ...

# %%
sns.countplot(x=df['Occupation'],hue=df.Gender)
plt.xticks(rotation=90)
plt.title('Distribution of Occupations by Gender')
# Out:
# Text(0.5, 1.0, 'Distribution of Occupations by Gender')

# %%
df['Occupation'].value_counts()
# Out:
# Occupation
# Nurse                   73
# Doctor                  71
# Engineer                63
# Lawyer                  47
# Teacher                 40
# Accountant              37
# Salesperson             32
# Software Engineer        4
# Scientist                4
# Sales Representative     2
# Manager                  1
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Gender'],hue=df['Sleep Disorder']);

# %%
df['BMI Category'].value_counts()
# Out:
# BMI Category
# Normal           195
# Overweight       148
# Normal Weight     21
# Obese             10
# Name: count, dtype: int64

# %%
df['BMI Category'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Distribution of BMI Categories');
plt.legend()

# %%
sns.lineplot(y=df['Occupation'], x=df['Stress Level'])
plt.title("Stress Level by Occupation")
# Out:
# C:\Users\harin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\harin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Stress Level by Occupation')

# %%
sns.lineplot(y=df['Occupation'],x=df['Sleep Duration'])
plt.title("Sleep Duration by Occupation")
# Out:
# C:\Users\harin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\harin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Sleep Duration by Occupation')

# %%
sns.scatterplot(x=df['Sleep Duration'],y=df['Age'],hue=df['Gender'])
plt.title("Relationship between Age,Sleep Duration by Gender")
# Out:
# Text(0.5, 1.0, 'Relationship between Age,Sleep Duration by Gender')

# %%
sns.scatterplot(x=df['Daily Steps'],y=df['Heart Rate'],hue=df['Gender'])
plt.title("Relationship between Daily Steps,Heart Rate by Gender")
# Out:
# Text(0.5, 1.0, 'Relationship between Daily Steps,Heart Rate by Gender')

# %%
sns.scatterplot(x=df['Age'],y=df['Stress Level'],hue=df['BMI Category'])
# Out:
# <Axes: xlabel='Age', ylabel='Stress Level'>

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
plt.title("Heatmap")
# Out:
# Text(0.5, 1.0, 'Heatmap')

# %%
X=df.drop("Sleep Disorder",axis=1)
y=df['Sleep Disorder']

# %%
X=pd.get_dummies(X,drop_first=True)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.naive_bayes import GaussianNB,BernoulliNB

# %%
cla = GaussianNB()
cla.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred=cla.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8666666666666667

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[16,  2,  2],
#        [ 2, 39,  0],
#        [ 1,  1, 12]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     Insomnia       0.84      0.80      0.82        20
#         None       0.93      0.95      0.94        41
#  Sleep Apnea       0.86      0.86      0.86        14
#
#     accuracy                           0.89        75
#    macro avg       0.88      0.87      0.87        75
# weighted avg       0.89      0.89      0.89        75
